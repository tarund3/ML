# %%
import yfinance as yf
import pandas as pd

# Fetch Microsoft stock data
df = yf.download('MSFT', start='1986-01-01', end='2023-12-31')

# Reset index to make 'Date' a column
df = df.reset_index()
df = df[['Date', 'Close']]
# Access specific columns
print(df)  # Access 'Date' and 'Close' columns after resetting index
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Date       Close
# Ticker                                  MSFT
# 0      1986-03-13 00:00:00+00:00    0.097222
# 1      1986-03-14 00:00:00+00:00    0.100694
# 2      1986-03-17 00:00:00+00:00    0.102431
# 3      1986-03-18 00:00:00+00:00    0.099826
# 4      1986-03-19 00:00:00+00:00    0.098090
# ...                          ...         ...
# 9522   2023-12-22 00:00:00+00:00  374.579987
# 9523   2023-12-26 00:00:00+00:00  374.660004
# 9524   2023-12-27 00:00:00+00:00  374.070007
# 9525   2023-12-28 00:00:00+00:00  375.279999
# 9526   2023-12-29 00:00:00+00:00  376.040009
#
# [9527 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df['Date'], df['Close'])

# %%
# A supervised learning model is a type of machine learning model that learns to make predictions or decisions based on labeled training data. It operates under the guidance of a "supervisor," 
# meaning the model is trained on a dataset where the input features (independent variables) and their corresponding target outputs (dependent variables) are provided.

import numpy as np

def df_to_window_dataset(df, first_date_str, last_date_str, window_siz, batch_size, shuffle_buffer):
